# %%
import pandas as pd

# %%
df=pd.read_csv('/content/startup_cleaned.csv')
df.head()
# Out:
#      company_brand                sector     stage  amount_usd  \
# 0  thecollegefever       Brand Marketing      seed      3654.0
# 1  happy cow dairy           Agriculture      seed    584710.0
# 2       myloancare                Credit  series a    950153.0
# 3      payme india    Financial Services     angel     29235.0
# 4         eunimart  E-Commerce Platforms      seed         NaN
#
#                                         what_it_does  year       city
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018  Bengaluru
# 1  A startup which aggregates milk from dairy far...  2018     Mumbai
# 2          Leading Online Loans Marketplace in India  2018   Gurugram
# 3  PayMe India is an innovative FinTech organizat...  2018      Noida
# 4  Eunimart is a one stop solution for merchants ...  2018  Hyderabad

# %%
df.shape
# Out:
# (2796, 7)

# %%
df.columns.tolist()
# Out:
# ['company_brand',
#  'sector',
#  'stage',
#  'amount_usd',
#  'what_it_does',
#  'year',
#  'city']

# %%
df.isna().sum()
# Out:
# company_brand      0
# sector            48
# stage            914
# amount_usd       540
# what_it_does       0
# year               0
# city             113
# dtype: int64

# %%
df.dtypes
# Out:
# company_brand     object
# sector            object
# stage             object
# amount_usd       float64
# what_it_does      object
# year               int64
# city              object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['city'].isna().sum()
# Out:
# np.int64(113)

# %%
#standardisizing the city values
#Keep the existing city when a condition is true; otherwise replace it with Python's None as it maps naturally to SQL NULL.
df['city'] = df['city'].where(df['city'].notna(), None)

# %%
print(df['city'].isna().sum())
# Out:
# 113

# %%
#saving the validated dataset
df.to_csv("startups_v1_clean.csv", index=False)

# %%
from google.colab import files
files.download('startups_v1_clean.csv')
